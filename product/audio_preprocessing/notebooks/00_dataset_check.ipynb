# %%
import pandas as pd, os

meta = pd.read_csv(r"C:\FYP\PROJECT\product\audio_preprocessing\data\ESC-50\meta\esc50.csv")
print(len(meta))
print("Audio files found:", len(os.listdir(r"C:\FYP\PROJECT\product\audio_preprocessing\data\ESC-50\audio")))

# This script checks the integrity of the ESC-50 dataset by verifying
# the number of metadata entries and audio files present in the specified directories.
# Out:
# 2000
# Audio files found: 2000
