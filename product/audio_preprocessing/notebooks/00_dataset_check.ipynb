# %%
from pathlib import Path
import pandas as pd
PROJECT_ROOT = Path(r"C:\FYP\PROJECT")

AUDIO_PREPROC_ROOT = PROJECT_ROOT / "product" / "audio_preprocessing"
meta_path = AUDIO_PREPROC_ROOT / "data" / "ESC-50" / "meta" / "esc50.csv"
audio_dir = AUDIO_PREPROC_ROOT / "data" / "ESC-50" / "audio"

print("Looking for meta at:", meta_path)
print("Exists?", meta_path.exists())
print("Looking for audio dir:", audio_dir)
print("Exists?", audio_dir.exists())

meta = pd.read_csv(meta_path)
print("Rows in esc50.csv:", len(meta))
print("Audio files found:", len(list(audio_dir.glob("*.wav"))))
# This script checks the integrity of the ESC-50 dataset by verifying
# the number of metadata entries and audio files present in the specified directories.
# Out:
# Looking for meta at: C:\FYP\PROJECT\product\audio_preprocessing\data\ESC-50\meta\esc50.csv
# Exists? True
# Looking for audio dir: C:\FYP\PROJECT\product\audio_preprocessing\data\ESC-50\audio
# Exists? True
# Rows in esc50.csv: 2000
# Audio files found: 2000
